# %% [markdown]
# # 🦀 Kafka Consumer
# ---

# %% [markdown]
# The first step is to install the required libraries, in our case `kafka-python` (and `pandas` to support visualization)

# %% [markdown]
# Now let's consume the messages, by creating a **Kafka Consumer**
#
# ![Kafka Consumer](images/consumer.png)

# %%
from kafka import KafkaConsumer
from config.kafka_config import *
import json
group_id = "my_pizza_group"

consumer = KafkaConsumer(
 client_id = "client1",
 group_id = group_id,
 **kafka_connection,
 value_deserializer = lambda v: json.loads(v.decode('ascii')),
 key_deserializer = lambda v: json.loads(v.decode('ascii')),
 max_poll_records = 10,
 consumer_timeout_ms = timeout_ms
)

# %% [markdown]
# Check out topics

# %%
consumer.topics()
# Out:
# {'_connect-configs', '_connect-offsets', '_connect-status', 'pizzas'}

# %% [markdown]
# and subscribe to the topic

# %%
consumer.subscribe(topics=[topic_name])
consumer.subscription()
# Out:
# {'pizzas'}

# %% [markdown]
# Now we start reading

# %%
for message in consumer:
    print ("%d:%d: k=%s v=%s" % (message.partition,
                                 message.offset,
                                 message.key,
                                 message.value))
# Out:
# 0:4: k={'id': 1} v={'name': '👨 Francesco', 'pizza': 'Margherita 🍕'}
# 0:5: k={'id': 2} v={'name': '👩 Adele', 'pizza': 'Hawaii 🍕+🍍+🥓'}
# 0:6: k={'id': 3} v={'name': '👦 Mark', 'pizza': 'Choccolate 🍕+🍫'}
# 0:7: k={'id': 4} v={'name': '👨 Dan', 'pizza': 'Fries 🍕+🍟'}
